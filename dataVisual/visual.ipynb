# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

bulan = ['januari','februari','maret','april','mei','juni','juli','agustus','september','oktober','november','desember']

#pengeluaran antara 500.000 - 2.000.000

minggu_1 = np.random.randint(500000,2000001,12)
minggu_2 = np.random.randint(500000,2000001,12)
minggu_3 = np.random.randint(500000,2000001,12)
minggu_4 = np.random.randint(500000,2000001,12)

data = {
    'bulan' : bulan,
    'minggu_1' : minggu_1,
    'minggu_2': minggu_2,
    'minggu_3': minggu_3,
    'minggu_4': minggu_4
}

df = pd.DataFrame(data)

df['total pengeluaran'] = df[['minggu_1','minggu_2','minggu_3','minggu_4']].sum(axis = 1)
df
# Out:
#         bulan  minggu_1  minggu_2  minggu_3  minggu_4  total pengeluaran
# 0     januari    951378    874268   1894570   1588068            5308284
# 1    februari   1513794   1641116   1191932   1501220            5848062
# 2       maret    949631    548152   1691706   1251518            4441007
# 3       april   1719606    781278   1481733    978172            4960789
# 4         mei    613626   1809649   1593800    592342            4609417
# 5        juni   1637847   1443289   1041175    573381            4695692
# 6        juli   1409905    676045   1083774   1157816            4327540
# 7     agustus   1949866   1953349   1924163    561958            6389336
# 8   september   1411195   1875967   1063594    552844            4903600
# 9     oktober   1251393   1636322   1187454   1168019            5243188
# 10   november    532363   1319822   1225145    558526            3635856
# 11   desember   1038108    971959    898549    802827            3711443

# %%
#total pengeluaran perbulan

plt.figure(figsize=(12,6))#canvas dengan ukuran width,height(inch)
plt.title('Total Pengeluaran Per bulan')
plt.bar(df['bulan'],df['total pengeluaran'],color='skyblue')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#scatter plot untuk analisa data pengeluaran per minggu per bulan

plt.figure(figsize=(12,6))
for minggu in ['minggu_1','minggu_2','minggu_3','minggu_4']:
    plt.plot(df['bulan'],df[minggu],marker='o',label=minggu)
    
plt.title("Pengeluaran Per minggu")
plt.xlabel('bulan')
plt.ylabel('pengeluaran(Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#pie chart->prasentase

plt.figure(figsize=(6,6))
plt.pie(df['total pengeluaran'],labels=df['bulan'],startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['bulan_angka'] = np.arange(1,13)

x = df[['bulan_angka']]
y = df['total pengeluaran']

model = LinearRegression()

model.fit(x,y)

prediksi = model.predict([[13]])[0]
print(f"hasil prediksi adalah:{prediksi}")
# Out:
# hasil prediksi adalah:4221922.878787878
# C:\Users\komputer jarkom 3\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('dt_msyrkt_yng_brprtsps_dlm_pmbrdyn_msyrkt_d_kcmtn_3.csv')
df
# Out:
#    id  kode_kabupaten    nama_kabupaten kode_kecamatan nama_kecamatan  \
# 0   1            3216  KABUPATEN BEKASI       32.16.13      PEBAYURAN
#
#                                        nama_variabel  jumlah satuan  tahun
# 0  DATA MASYARAKAT YANG  BERPARTISIPASI DALAM PEM...     280  ORANG   2024

# %%
<h1>skenario analisis data</h1>
<ol>
<li>menyatakan kode Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data numerik.</li>
<li> menyatakan lingkup data berasal dari wilayah Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data teks.</li>
<li> menyatakan kode dari setiap kabupaten dan kota di Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data numerik.</li>
<li> menyatakan lingkup data berasal dari setiap kabupaten dan kota di Provinsi Jawa Barat sesuai penamaan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data teks.</li>
<li> menyatakan kode dari setiap kecamatan di Provinsi Jawa Barat sesuai ketentuan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data numerik.</li>
<li> menyatakan lingkup data berasal dari setiap kecamatan di Provinsi Jawa Barat sesuai penamaan BPS merujuk pada aturan Peraturan Badan Pusat Statistik Nomor 3 Tahun 2019 dengan tipe data teks.</li>
</ol>
